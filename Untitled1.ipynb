# %%
a=1
b=2
c=3
d=4

# %%
a+b, a-b, a+c
# Out:
# (3, -1, 4)

# %%
print(a+b)
print(a+b, a-b, a*c)
# Out:
# 3
# 3 -1 3

# %%
print(a*b)
print(d/b)
print(d%c)
# Out:
# 2
# 2.0
# 1

# %%
a=input()
# Out:
#  10

# %%
type(a)
# Out:
# str

# %%
a=float(input())
# Out:
#  10

# %%
type(a)
# Out:
# float

# %%
a-=int(input())
# Out:
#  10

# %%
type(a)
# Out:
# float

# %%
a=123
b=-123
c=0

# %%
type(a)

# %%
a=1.2
b=-2.1

# %%
type(b)

# %%
"Life is too short, you need Python"

# %%
"A"

# %%
"123"
# Out:
# '123'

# %%
food = "Python's favorite food is perl"

# %%
type(food)
# Out:
# str

# %%
python='python'

# %%
a="python"
b=2

# %%
a*b
# Out:
# 'pythonpython'

# %%
print("="*50)
print("My Program")
print("="*50)
# Out:
# ==================================================
# My Program
# ==================================================

# %%
A =[1,2,3,4,5]
type(A)
# Out:
# list

# %%
B=list[1,2,3,4,5]
type(B) #실행은 되지만 사용하지 않음
# Out:
# types.GenericAlias

# %%
a = "독고영재, 50"
b = "김철수, 30"
리스트명 = ["독고영재, 50","김철수, 30"]
c = [a, b]

print(리스트명, c)
# Out:
# ['독고영재, 50', '김철수, 30'] ['독고영재, 50', '김철수, 30']

# %%
import numpy as np

# %%
a=np.array([1,2,3])
b=np.array([5,6,7])
c=a+b
print(c, c.shape)
type(c)
# Out:
# [ 6  8 10] (3,)
# numpy.ndarray

# %%
a=[1,2,3]
b=[5,6,7]
c=a+b
print(c, np.array(a))
type(c)
# Out:
# [1, 2, 3, 5, 6, 7] [1 2 3]
# list

# %%
D=[1,2,4,"a"]
e= np.array(D)
print(D, e)
#a를 숫자로 바꿀 수 없으니 다 문자형으로 바꿔주겠긔... 
#배열의 자료형은 하나만 가능, 벡터는 여러개 가능(계산불가능)
# Out:
# [1, 2, 4, 'a'] ['1' '2' '4' 'a']

# %%
a=np.array([[1,2,3],[4,5,6]])
b=np.array([[5,6,7], [8,9,10]])
c=a+b
print(type(c), c.shape)
# Out:
# <class 'numpy.ndarray'> (2, 3)

# %%
a=np.array([[[1,3,4],[4,5,6],[7,8,9]]])
a.shape
# Out:
# (1, 3, 3)

# %%
a = [1,5,7,8,10,"안녕","a"]
print(a)
# Out:
# [1, 5, 7, 8, 10, '안녕', 'a']

# %%
a = [1,2,4,5]
b=[2,3,4,6]
a+b
# Out:
# [1, 2, 4, 5, 2, 3, 4, 6]

# %%
a = np.array([1,2,3,4,5,6,20,19,18,17,16,15])
print(a)
# Out:
# [ 1  2  3  4  5  6 20 19 18 17 16 15]

# %%
print("-"*50, "\n 데이터 전처리 수업 \n 끝 \n", "="*50)
# Out:
# --------------------------------------------------
#  데이터 전처리 수업
#  끝
#  ==================================================
